# %% [markdown]
# # SENG 207 - PROJECT 1
# ## NAME: AGYAPONG SAMUEL BAFFOUR
# ## ID: 10988638
# ## DEPARTMENT: BMEN

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib as mpl
import numpy as np
import seaborn as sns

# %%
data_raw = pd.read_csv("data.csv")
data_raw
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data_final = data_raw.fillna(data_raw.mean(), inplace=False)
data_final
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %% [markdown]
# ### The mean is commonly used as a method for cleaning data in pandas because it provides a measure of the central tendency of a dataset. When dealing with a large dataset, there may be missing or inaccurate values that can skew the overall results. By replacing these missing or inaccurate values with the mean, the resulting dataset can be more representative of the true values of the data.

# %%
data_final.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %%
data_final.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## DATA INFERENCE

# %%
data_inf = data_final.iloc[:, 1:].describe()
data_inf
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1601.000000       1601.000000  1601.000000     1601.000000
# mean        8.319875          0.527742     0.271175        2.538445
# std         1.739495          0.178981     0.194684        1.409138
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1601.000000          1601.000000           1601.000000  1601.000000
# mean      0.087487            15.886875             46.520000     0.996746
# std       0.047032            10.455218             32.967416     0.001887
# ...

# %%
mode_data_final = data_final.iloc[:, 1:].mode().iloc[0]
median_data_final = data_final.iloc[:, 1:].median()
print("Mode:")
print(mode_data_final)
print("\nMedian:")
print(median_data_final)
# Out:
# Mode:
# fixed acidity            7.2000
# volatile acidity         0.6000
# citric acid              0.0000
# residual sugar           2.0000
# chlorides                0.0800
# free sulfur dioxide      6.0000
# total sulfur dioxide    28.0000
# density                  0.9972
# pH                       3.3000
# sulphates                0.6000
# alcohol                  9.5000
# quality                  5.0000
# Name: 0, dtype: float64
#
# Median:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
histogram_plot1 = sns.histplot(data=data_final, x='fixed acidity')

histogram_plot1.set_title("Histogram plot for fixed acidity")
# Out:
# Text(0.5, 1.0, 'Histogram plot for fixed acidity')

# %%
mean_1 = data_final['fixed acidity'].mean()


above_mean_count = data_final[data_final['fixed acidity'] > mean_1]['fixed acidity'].count()
below_mean_count = data_final[data_final['fixed acidity'] < mean_1]['fixed acidity'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['red', 'blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Fixed Acidity Greater than and Less than Mean')
plt.show()

# %%
histogram_plot2 = sns.histplot(data=data_final, x='volatile acidity')

histogram_plot2.set_title("Histogram plot for volatile acidity")
# Out:
# Text(0.5, 1.0, 'Histogram plot for volatile acidity')

# %%
mean_1 = data_final['volatile acidity'].mean()


above_mean_count = data_final[data_final['volatile acidity'] > mean_1]['volatile acidity'].count()
below_mean_count = data_final[data_final['volatile acidity'] < mean_1]['volatile acidity'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['orange','green']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Volatile Acidity Greater than and Less than Mean')
plt.show()

# %%
histogram_plot3 = sns.histplot(data=data_final, x='citric acid')

histogram_plot3.set_title("Histogram plot for citric acid")
# Out:
# Text(0.5, 1.0, 'Histogram plot for citric acid')

# %%
mean_1 = data_final['citric acid'].mean()


above_mean_count = data_final[data_final['citric acid'] > mean_1]['citric acid'].count()
below_mean_count = data_final[data_final['citric acid'] < mean_1]['citric acid'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['yellow', 'red']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Citric Acid Greater than and Less than Mean')
plt.show()

# %%
histogram_plot4 = sns.histplot(data=data_final, x='residual sugar')

histogram_plot4.set_title("Histogram plot for residual sugar")
# Out:
# Text(0.5, 1.0, 'Histogram plot for residual sugar')

# %%
mean_1 = data_final['residual sugar'].mean()


above_mean_count = data_final[data_final['residual sugar'] > mean_1]['residual sugar'].count()
below_mean_count = data_final[data_final['residual sugar'] < mean_1]['residual sugar'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['green', 'red']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Residual Sugar Greater than and Less than Mean')
plt.show()

# %%
histogram_plot5 = sns.histplot(data=data_final, x='chlorides')

histogram_plot5.set_title("Histogram plot for chlorides")
# Out:
# Text(0.5, 1.0, 'Histogram plot for chlorides')

# %%
mean_1 = data_final['chlorides'].mean()


above_mean_count = data_final[data_final['chlorides'] > mean_1]['chlorides'].count()
below_mean_count = data_final[data_final['chlorides'] < mean_1]['chlorides'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['orange', 'red']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Chlorides Greater than and Less than Mean')
plt.show()

# %%
histogram_plot6 = sns.histplot(data=data_final, x='free sulfur dioxide')

histogram_plot6.set_title("Histogram plot for free sulfur dioxide")
# Out:
# Text(0.5, 1.0, 'Histogram plot for free sulfur dioxide')

# %%
mean_1 = data_final['free sulfur dioxide'].mean()


above_mean_count = data_final[data_final['free sulfur dioxide'] > mean_1]['free sulfur dioxide'].count()
below_mean_count = data_final[data_final['free sulfur dioxide'] < mean_1]['free sulfur dioxide'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['red', 'yellow']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Free Sulfur Dioxide Greater than and Less than Mean')
plt.show()

# %%
histogram_plot7 = sns.histplot(data=data_final, x='total sulfur dioxide')

histogram_plot7.set_title("Histogram plot for total sulfur dioxide")
# Out:
# Text(0.5, 1.0, 'Histogram plot for total sulfur dioxide')

# %%
mean_1 = data_final['total sulfur dioxide'].mean()


above_mean_count = data_final[data_final['total sulfur dioxide'] > mean_1]['total sulfur dioxide'].count()
below_mean_count = data_final[data_final['total sulfur dioxide'] < mean_1]['total sulfur dioxide'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'green']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Total Sulfur Dioxide Greater than and Less than Mean')
plt.show()

# %%
histogram_plot8 = sns.histplot(data=data_final, x='density')

histogram_plot8.set_title("Histogram plot for density")
# Out:
# Text(0.5, 1.0, 'Histogram plot for density')

# %%
mean_1 = data_final['density'].mean()


above_mean_count = data_final[data_final['density'] > mean_1]['density'].count()
below_mean_count = data_final[data_final['density'] < mean_1]['density'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['orange', 'red']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Density Greater than and Less than Mean')
plt.show()

# %%
histogram_plot9 = sns.histplot(data=data_final, x='pH')

histogram_plot9.set_title("Histogram plot for pH")
# Out:
# Text(0.5, 1.0, 'Histogram plot for pH')

# %%
mean_1 = data_final['pH'].mean()


above_mean_count = data_final[data_final['pH'] > mean_1]['pH'].count()
below_mean_count = data_final[data_final['pH'] < mean_1]['pH'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['brown', 'black']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('pH Greater than and Less than Mean')
plt.show()

# %%
histogram_plot10 = sns.histplot(data=data_final, x='sulphates')

histogram_plot10.set_title("Histogram plot for sulphates")
# Out:
# Text(0.5, 1.0, 'Histogram plot for sulphates')

# %%
mean_1 = data_final['sulphates'].mean()


above_mean_count = data_final[data_final['sulphates'] > mean_1]['sulphates'].count()
below_mean_count = data_final[data_final['sulphates'] < mean_1]['sulphates'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['lightblue', 'yellow']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Sulphates Greater than and Less than Mean')
plt.show()

# %%
histogram_plot11 = sns.histplot(data=data_final, x='alcohol')

histogram_plot11.set_title("Histogram plot for alcohol")
# Out:
# Text(0.5, 1.0, 'Histogram plot for alcohol')

# %%
mean_1 = data_final['alcohol'].mean()


above_mean_count = data_final[data_final['alcohol'] > mean_1]['alcohol'].count()
below_mean_count = data_final[data_final['alcohol'] < mean_1]['alcohol'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['red', 'brown']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Alcohol Greater than and Less than Mean')
plt.show()

# %%
histogram_plot12 = sns.histplot(data=data_final, x='quality')

histogram_plot12.set_title("Histogram plot for quality")
# Out:
# Text(0.5, 1.0, 'Histogram plot for quality')

# %%
mean_1 = data_final['quality'].mean()


above_mean_count = data_final[data_final['quality'] > mean_1]['quality'].count()
below_mean_count = data_final[data_final['quality'] < mean_1]['quality'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['black', 'green']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Quality Greater than and Less than Mean')
plt.show()

# %%
col = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']
cor= data_final[col].corr()
fig,ax = plt.subplots(figsize=(11, 6)) 
heatmap = sns.heatmap(cor, annot=True, cmap='viridis',ax=ax)
heatmap.set_xticklabels(heatmap.get_xticklabels())
# Out:
# [Text(0.5, 0, 'fixed acidity'),
#  Text(1.5, 0, 'volatile acidity'),
#  Text(2.5, 0, 'citric acid'),
#  Text(3.5, 0, 'residual sugar'),
#  Text(4.5, 0, 'chlorides'),
#  Text(5.5, 0, 'free sulfur dioxide'),
#  Text(6.5, 0, 'total sulfur dioxide'),
#  Text(7.5, 0, 'density'),
#  Text(8.5, 0, 'pH'),
#  Text(9.5, 0, 'sulphates'),
#  Text(10.5, 0, 'alcohol'),
#  Text(11.5, 0, 'quality')]
